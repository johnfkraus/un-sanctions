# %%
import xmltodict
import json
import pandas as pd
import numpy as np

# with open('consol.xml', 'r') as f:
with open('consolidated.xml', 'r') as f:
    data = f.read()

cons_dict = xmltodict.parse(data)
cons_json = json.dumps(cons_dict, indent=2)
print(cons_json[:2000])
# Out:
# {
#   "CONSOLIDATED_LIST": {
#     "@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance",
#     "@xsi:noNamespaceSchemaLocation": "https://www.un.org/sc/resources/sc-sanctions.xsd",
#     "@dateGenerated": "2022-10-21T20:40:12.605-04:00",
#     "INDIVIDUALS": {
#       "INDIVIDUAL": [
#         {
#           "DATAID": "6908555",
#           "VERSIONNUM": "1",
#           "FIRST_NAME": "RI",
#           "SECOND_NAME": "WON HO",
#           "THIRD_NAME": null,
#           "UN_LIST_TYPE": "DPRK",
#           "REFERENCE_NUMBER": "KPi.033",
#           "LISTED_ON": "2016-11-30",
#           "COMMENTS1": "Ri Won Ho is a DPRK Ministry of State Security Official stationed in Syria supporting KOMID.",
#           "DESIGNATION": {
#             "VALUE": "DPRK Ministry of State Security Official"
#           },
#           "NATIONALITY": {
#             "VALUE": "Democratic People's Republic of Korea"
#           },
#           "LIST_TYPE": {
#             "VALUE": "UN List"
#           },
#           "LAST_DAY_UPDATED": {
#             "VALUE": null
#           },
#           "INDIVIDUAL_ALIAS": {
#             "QUALITY": null,
#             "ALIAS_NAME": null
#           },
#           "INDIVIDUAL_ADDRESS": {
#             "COUNTRY": null
#           },
#           "INDIVIDUAL_DATE_OF_BIRTH": {
#             "TYPE_OF_DATE": "EXACT",
#             "DATE": "1964-07-17"
#           },
#           "INDIVIDUAL_PLACE_OF_BIRTH": null,
#           "INDIVIDUAL_DOCUMENT": {
#             "TYPE_OF_DOCUMENT": "Passport",
#             "NUMBER": "381310014"
#           },
#           "SORT_KEY": null,
#           "SORT_KEY_LAST_MOD": null
#         },
#         {
#           "DATAID": "6908570",
#           "VERSIONNUM": "1",
#           "FIRST_NAME": "CHANG",
#           "SECOND_NAME": "CHANG HA",
#           "THIRD_NAME": null,
#           "UN_LIST_TYPE": "DPRK",
#           "REFERENCE_NUMBER": "KPi.037",
#           "LISTED_ON": "2016-11-30",
#           "COMMENTS1": null,
#           "DESIGNATION": {
#             "VALUE": "President of the Second Academy of Natural Sciences (SANS)"
#           },

# %%
indivs = cons_dict['CONSOLIDATED_LIST']['INDIVIDUALS']['INDIVIDUAL']
entities = cons_dict['CONSOLIDATED_LIST']['ENTITIES']['ENTITY']
print(type(indivs))  # list

df_ind_norm = pd.json_normalize(indivs,
                                    meta=[
                                          ['INDIVIDUAL_ADDRESS', 'COUNTRY', 'STATE_PROVINCE','ZIP_CODE', 'NOTE'],
                                          ['INDIVIDUAL_DOCUMENT', 'TYPE_OF_DOCUMENT', 'NUMBER', 'ISSUING_COUNTRY', 'NOTE'],
                                    ['INDIVIDUAL_DATE_OF_BIRTH', 'TYPE_OF_DATE', 'DATE'],
                                    ['INDIVIDUAL_ALIAS', 'QUALITY', 'ALIAS_NAME'],
                                     ['INDIVIDUAL_PLACE_OF_BIRTH','CITY', 'STATE_PROVINCE', 'COUNTRY']
                                          ]                                   
                                   )  #, record_path =['INDIVIDUAL'])
# Out:
# <class 'list'>

# %%
entities = cons_dict['CONSOLIDATED_LIST']['ENTITIES']['ENTITY']
ent_json = json.dumps(entities, indent=2)
# print(ent_json[:1000])
df_ent_norm = pd.json_normalize(entities, meta=[
                                            ['ENTITY_ADDRESS','STREET', 'CITY', 'COUNTRY','STATE_PROVINCE','ZIP_CODE', 'NOTE'],
                                            ['ENTITY_ALIAS', 'QUALITY', 'ALIAS_NAME']
])
 
df_ent_norm = df_ent_norm.drop(columns=['SORT_KEY', 'SORT_KEY_LAST_MOD','ENTITY_ADDRESS', 'ENTITY_ALIAS'])
df_ent_norm.info()
df_ent_norm

# ,
#                                     meta=[
#                                           ['INDIVIDUAL_ADDRESS', 'COUNTRY', 'STATE_PROVINCE','ZIP_CODE', 'NOTE'],
#                                           ['INDIVIDUAL_DOCUMENT', 'TYPE_OF_DOCUMENT', 'NUMBER', 'ISSUING_COUNTRY', 'NOTE'],
#                                     ['INDIVIDUAL_DATE_OF_BIRTH', 'TYPE_OF_DATE', 'DATE'],
#                                     ['INDIVIDUAL_ALIAS', 'QUALITY', 'ALIAS_NAME'],
#                                      ['INDIVIDUAL_PLACE_OF_BIRTH','CITY', 'STATE_PROVINCE', 'COUNTRY']
#                                           ]                                   
#                                    )  #, record_path =['INDIVIDUAL'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DATAID                         253 non-null    object
#  1   VERSIONNUM                     253 non-null    object
#  2   FIRST_NAME                     253 non-null    object
#  3   UN_LIST_TYPE                   253 non-null    object
#  4   REFERENCE_NUMBER               253 non-null    object
#  5   LISTED_ON                      253 non-null    object
#  6   COMMENTS1                      246 non-null    object
#  7   LIST_TYPE.VALUE                253 non-null    object
#  8   LAST_DAY_UPDATED.VALUE         114 non-null    object
#  9   ENTITY_ALIAS.QUALITY           38 non-null     object
#  10  ENTITY_ALIAS.ALIAS_NAME        38 non-null     object
#  11  ENTITY_ADDRESS.CITY            83 non-null     object
#  12  ENTITY_ADDRESS.COUNTRY         118 non-null    object
#  13  ENTITY_ADDRESS.NOTE            12 non-null     object
#  14  ENTITY_ADDRESS.STATE_PROVINCE  16 non-null     object
#  15  NAME_ORIGINAL_SCRIPT           44 non-null     object
#  16  ENTITY_ADDRESS.STREET          65 non-null     object
#  17  ENTITY_ADDRESS.ZIP_CODE        6 non-null      object
#  18  SUBMITTED_ON                   1 non-null      object
# dtypes: object(19)
# memory usage: 37.7+ KB
#       DATAID VERSIONNUM                                 FIRST_NAME  \
# 0    6908629          1  PROPAGANDA AND AGITATION DEPARTMENT (PAD)
# 1     110403          1                                 7TH OF TIR
# 2    6908409          1              ABDALLAH AZZAM BRIGADES (AAB)
# 3     113445          1                           ABU SAYYAF GROUP
# 4     110402          1            ABZAR BORESH KAVEH CO. (BK CO.)
# ..       ...        ...                                        ...
# 248  6908697          1              WEIHAI WORLD-SHIPPING FREIGHT
# 249   110328          1                  YA MAHDI INDUSTRIES GROUP
# 250   110327          1                                    YAS AIR
# 251   110326          1           YAZD METALLURGY INDUSTRIES (YMI)
# 252  6908689          1                    YUK TUNG ENERGY PTE LTD
#
#     UN_LIST_TYPE REFERENCE_NUMBER   LISTED_ON  \
# 0           DPRK          KPe.053  2017-09-11
# 1           Iran          IRe.001  2006-12-23
# 2       Al-Qaida          QDe.144  2014-09-23
# 3       Al-Qaida          QDe.001  2001-10-06
# 4           Iran          IRe.002  2008-03-03
# ..           ...              ...         ...
# 248         DPRK          KPe.074  2018-03-30
# 249         Iran          IRe.076  2007-03-24
# 250         Iran          IRe.077  2012-12-20
# 251         Iran          IRe.078  2010-06-09
# 252         DPRK          KPe.075  2018-03-30
#
#                                              COMMENTS1 LIST_TYPE.VALUE  \
# 0    The Propaganda and Agitation Department has fu...         UN List
# 1    Subordinate of Defence Industries Organisation...         UN List
# 2    An armed group that has carried out joint atta...         UN List
# 3    Associated with Jemaah Islamiyah (JI) (QDe.092...         UN List
# 4    Involved in the production of centrifuge compo...         UN List
# ..                                                 ...             ...
# 248  Ship and commercial manager of the XIN GUANG H...         UN List
# 249  Subordinate to AIO, which is involved in inter...         UN List
# 250  Yas Air is the new name for Pars Air, a compan...         UN List
# 251  YMI is a subordinate of DIO. [Old Reference #E...         UN List
# 252  Ship manager and commercial manager of the YUK...         UN List
#
#        LAST_DAY_UPDATED.VALUE ENTITY_ALIAS.QUALITY  ENTITY_ALIAS.ALIAS_NAME  \
# 0                        None                 None                     None
# 1                  2014-12-17                 None                     None
# 2                  2019-12-06                  NaN                      NaN
# 3    [2011-12-13, 2020-11-24]               a.k.a.  Al Harakat Al Islamiyya
# 4                  2014-12-17                 None                     None
# ..                        ...                  ...                      ...
# 248  [2018-05-23, 2022-09-14]                 None                     None
# 249                      None                 None                     None
# 250                      None                 None                     None
# 251                      None                  NaN                      NaN
# 252  [2020-05-11, 2022-07-26]                 None                     None
#
#     ENTITY_ADDRESS.CITY                 ENTITY_ADDRESS.COUNTRY  \
# 0             Pyongyang  Democratic People's Republic of Korea
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                            Philippines
# 4                   NaN                                    NaN
# ..                  ...                                    ...
# 248            Shandong                                  China
# 249                 NaN                                    NaN
# 250              Tehran             Iran (Islamic Republic of)
# 251                 NaN                                    NaN
# 252           Singapore                              Singapore
#
#                                    ENTITY_ADDRESS.NOTE  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Operates in Lebanon, Syria and the Arabian Pen...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 248                                                NaN
# 249                                                NaN
# 250                                                NaN
# 251                                                NaN
# 252                                                NaN
#
#     ENTITY_ADDRESS.STATE_PROVINCE NAME_ORIGINAL_SCRIPT  \
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
# ..                            ...                  ...
# 248                           NaN                  NaN
# 249                           NaN                  NaN
# 250                           NaN                  NaN
# 251                           NaN                  NaN
# 252                           NaN                  NaN
#
#                                  ENTITY_ADDRESS.STREET  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 248             419-201, Tongyi Lu, Huancui Qu, Weihai
# 249                                                NaN
# 250  Mehrabad International Airport, Next to Termin...
# 251                                                NaN
# 252                 80 Raffles Place, #17-22 UOB Plaza
#
#     ENTITY_ADDRESS.ZIP_CODE SUBMITTED_ON
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# ..                      ...          ...
# 248                  264200          NaN
# 249                     NaN          NaN
# 250                     NaN          NaN
# 251                     NaN          NaN
# 252                  048624          NaN
#
# [253 rows x 19 columns]

# %%
# pd.set_option('display.expand_frame_repr', True)
# pd.set_option('max_colwidth', -1)
import re
rstring = "(\([a-z]{3,4}.\d{3,4}\))"
# df_ind_norm['TARGETS'] = df_ind_norm.loc[:,'COMMENTS1'].str.findall(r'\([a-z]{3,4}.\d{3,4}\)', flags=re.IGNORECASE)

df_ind_norm['TARGETS'] = df_ind_norm.loc[:,'COMMENTS1'].str.findall(r'\(([A-Za-z]{3,4}.\d{3,4})\)', flags=re.IGNORECASE)

# re.MULTILINE | re.IGNORECASE

# regex = r"\(([A-Za-z]{3,4}.\d{3,4})\)"


df_ind_norm.loc[:,'TARGETS'] = [] if df_ind_norm.loc[:,'TARGETS'] is None else df_ind_norm.loc[:,'TARGETS']

# for i in range(df_ind_norm.shape[0]):
#     # source = df_ind_norm['REFERENCE_NUMBER'].loc[i]
#     if (df_ind_norm['TARGETS'].loc[i] is None):
#         df_ind_norm.at[i, 'TARGETS'] = []
#     # target_list_len = len(df_ind_norm['TARGETS'].loc(i))
#     for j, target_list in enumerate(df_ind_norm['TARGETS'].loc(i)):
#         # target.replace("(","").replace(")","")
#         for k, target in enumerate(target_list:
#             df_ind_norm['TARGETS'].loc(i)[j] = target.replace("(","").replace(")","")
# df_ind_norm.loc[:,'TARGETS'] = [[y.replace("(","").replace(")","") for y in x] for x in df_ind_norm.loc[:,'TARGETS']]
# df_ind_norm['TARGETS'] = [x.replace("(","").replace(")","") for x in df_ind_norm.loc[:,'COMMENTS1'].str.findall(r'\([a-z]{3,4}.\d{3,4}\)', flags=re.IGNORECASE)]
# df_ind_norm['TARGETS'] = [x.replace("(","").replace(")","")  for x in df_ind_norm.loc[:,'COMMENTS1'].str.findall(r'\([a-z]{3,4}.\d{3,4}\)', flags=re.IGNORECASE) if x is not None]
# print(df_ind_norm.loc[(df_ind_norm['TARGETS'].notnull()) & (df_ind_norm['CONN_COUNT']>1)],['TARGETS','CONN_COUNT'])
# df_ind_norm = df_ind_norm.astype({'TARGETS': int})

# %%
# df_ind_norm.rename(str.replace('INDIVIDUAL_',''), axis='columns')
df_ind_norm.columns = [c.replace("INDIVIDUAL_", "") for c in list(df_ind_norm.columns)]

# display(dataFrame.loc[(dataFrame['Salary']>=100000) & (dataFrame['Age']< 40) & (dataFrame['JOB'].str.startswith('D')),
# print(df_ind_norm[[(df_ind_norm.CONNECTIONS.notnull()) and ('CONN_COUNT'>1)]][['CONNECTIONS', 'COMMENTS1']])  # [['CONNECTIONS' == None]]
# https://regex101.com/r/ejCzvg/1
# [itm for itm in S.str.extractall('(.*)') if (itm is not None and len(str(itm))>0)]
# [itm[0] for itm in S.str.findall('(.*)') if (itm is not None and len(itm)>0)]
# [itm[0] for itm in S.str.findall('^[Ff].*') if (itm is not None and len(itm)>0)]

# %%
col_list = list(df_ind_norm.columns)
col_list.remove('TARGETS')

# %%
for column in ['THIRD_NAME', 'SECOND_NAME', 'FIRST_NAME','NATIONALITY.VALUE']:
    df_ind_norm.loc[:, column].replace(np.nan, '', inplace=True)
    print(df_ind_norm[column].value_counts())

# df_ind_norm[['SECOND_NAME','THIRD_NAME']].replace(np.nan, '', inplace=True)
# # df_ind_norm['SECOND_NAME'].replace(np.nan, '', inplace=True)
# Out:
#              361
# IBRAHIM       17
# HUSSEIN        6
# MUHAMMAD       6
# HASSAN         6
#             ...
# AZHAR          1
# AWAN           1
# ANWARI         1
# ASELDEROV      1
# NOORZAI        1
# Name: THIRD_NAME, Length: 281, dtype: int64
#                   9
# MOHAMED           8
# ALI               8
# HAQQANI           8
# MOHAMMED          7
#                  ..
# BYONG CHOL        1
# BWAMBALE          1
# YANGOUVONDA       1
# BEN ABDUL AZIZ    1
# ‘ABD AL-SALAM     1
# Name: SECOND_NAME, Length: 569, dtype: int64
# KIM         17
# MOHAMMAD    13
# RI          12
# ALI         10
# MOHAMMED     9
#             ..
# BOUBAKER     1
# MOKHTAR      1
# MAHMOOD      1
# AYYUB        1
# SAID JAN     1
# Name: FIRST_NAME, Length: 523, dtype: int64
# Afghanistan                              126
#                                           85
# Iraq                                      84
# Democratic People's Republic of Korea     79
# Indonesia                                 22
#                                         ...
# [Somalia, Sweden]                          1
# Trinidad and Tobago                        1
# Norway                                     1
# Senegal                                    1
# Turkey                                     1
# Name: NATIONALITY.VALUE, Length: 79, dtype: int64

# %%
for i in range(df_ind_norm.shape[0]):
    source = df_ind_norm['REFERENCE_NUMBER'].loc[i]
    if (df_ind_norm['TARGETS'].loc[i] is None):
        df_ind_norm.at[i, 'TARGETS'] = []

df_ind_norm['CONN_COUNT'] = df_ind_norm['TARGETS'].str.len().astype(int)
# df_ind_norm[['CONN_COUNT']] = df_ind_norm[['CONN_COUNT']].astype(int)
df_ind_norm["NAME"] = df_ind_norm['FIRST_NAME'].astype(str) +" "+ df_ind_norm["SECOND_NAME"] +" "+ df_ind_norm["THIRD_NAME"]

link_list = []

for i in range(df_ind_norm.shape[0]):
    source = df_ind_norm['REFERENCE_NUMBER'].loc[i]
    # if (df_ind_norm['TARGETS'].loc[i] is None):
    #     df_ind_norm.at[i, 'TARGETS'] = []

    if (df_ind_norm['TARGETS'].loc[i] is not None) and (len(df_ind_norm['TARGETS'].loc[i]) > 0):        
        # print(i, target_list.loc[i])
        targets_list = []
        for target in df_ind_norm['TARGETS'].loc[i]:
            # target = target.replace('(','').replace(')','')
            if source == target:
                print('WARNING', source, ' equals ', target)
            targets_list.append(target)
            name = df_ind_norm['NAME'].loc[i] 
            link2 = [df_ind_norm['REFERENCE_NUMBER'].loc[i], target, name]
            link_list.append(link2)
            df_ind_norm.at[i, 'TARGETS'] = targets_list

            # df_ind_norm['TARGETS'].loc[i] = targets_list

print(df_ind_norm['TARGETS'].value_counts())
t = df_ind_norm['TARGETS']
# Out:
# []                                      477
# [QDe.115]                                41
# [QDe.137]                                15
# [QDe.004]                                11
# [TAi.004]                                 9
#                                        ...
# [QDe.115, QDe.137, QDi.299, QDi.317]      1
# [QDe.134, QDe.141, QDe.115]               1
# [QDe.115, QDe.129]                        1
# [QDe.129, QDi.006]                        1
# [TAi.154]                                 1
# Name: TARGETS, Length: 118, dtype: int64

# %%
print(len(link_list))

df_edges = pd.DataFrame(link_list, columns=['Source', 'Target', 'Name'] )
df_edges.to_csv('un_indiv_edges.csv', index=False)
graph = dict(zip(df_ind_norm.REFERENCE_NUMBER, df_ind_norm.TARGETS))

print(len(graph.keys()))
graph_string = str(graph)
print(graph_string[:400])

# networkx attributes formatting:
# attrs = {0: {'attr1': 20, 'attr2': 'nothing'}, 1: {'attr2': 3}, 2: {'attr1': 42}, 3: {'attr3': 'hello'}, 4: {'attr1': 54, 'attr3': '33'}}
# nx.set_node_attributes(G, attrs)
# Out:
# 340
# 703
# {'KPi.033': [], 'KPi.037': [], 'KPi.038': [], 'QDi.430': ['QDe.115'], 'KPi.034': [], 'KPi.035': [], 'KPi.036': [], 'KPi.030': [], 'KPi.032': [], 'KPi.031': [], 'KPi.039': [], 'YEi.001': [], 'SOi.020': [], 'QDi.400': ['QDe.137'], 'QDi.343': ['QDe.004', 'QDe.137', 'QDe.115'], 'IRi.001': [], 'TAi.155': ['TAe.012', 'TAi.144'], 'QDi.012': ['QDe.098'], 'IQi.043': [], 'QDi.192': ['QDe.003'], 'TAi.121': [

# %%
# make REFERENCE_NUMBER the df index
df_ind_index = df_ind_norm.set_index('REFERENCE_NUMBER')
ind_dict_of_attrs = {}
# print(df_ind_index.index)

for i in df_ind_index.index:  # index is 'REFERENCE_NUMBER'
    # name_dict = {'NAME': df_ind_index.loc[i, 'NAME']}
    attr_dict = {'NAME': df_ind_index.loc[i, 'NAME']}
    # print(df_ind_index.loc[i, 'NATIONALITY.VALUE'])

    attr_dict['NATIONALITY'] = str(df_ind_index.loc[i, 'NATIONALITY.VALUE'])
    # print(attr_dict)
    ind_dict_of_attrs[i] = attr_dict

#importing pickle module
import pickle
# defining the dictionary
# records = { 
#         "subject1" : 'python', 
#         "subject2" : 'java', 
#         "subject3" : 'ruby', 
#         "subject4" : 'c++',
#         "subject5" : 'c' 
#         }
# Open file in write binary mode
# writing dictionary to file using pickle.dump method
pickle_filename = 'ind_attr_dict.pickle'
with open(pickle_filename, 'wb') as handle:
    pickle.dump(ind_dict_of_attrs, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Load data (deserialize) (test)
with open(pickle_filename, 'rb') as handle:
     unserialized_data = pickle.load(handle)

print(ind_dict_of_attrs == unserialized_data)
# Out:
# Index(['KPi.033', 'KPi.037', 'KPi.038', 'QDi.430', 'KPi.034', 'KPi.035',
#        'KPi.036', 'KPi.030', 'KPi.032', 'KPi.031',
#        ...
#        'CDi.031', 'LYi.020', 'QDi.223', 'IRi.043', 'IQi.009', 'LYi.023',
#        'LYi.026', 'QDi.426', 'TAi.153', 'QDi.289'],
#       dtype='object', name='REFERENCE_NUMBER', length=703)
# {'NAME': 'RI WON HO ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'CHANG CHANG HA ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'CHO CHUN RYONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'EMRAAN ALI ', 'NATIONALITY': "['Trinidad and Tobago', 'United States of America']"}
# {'NAME': 'JO YONG CHOL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM CHOL SAM ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM SOK CHOL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM SONG CHOL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM SE GON ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'SON JONG HYOK ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'SON MUN SAN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'ABD AL-KHALIQ AL-HOUTHI', 'NATIONALITY': 'Yemen'}
# {'NAME': 'MAHAD KARATE ', 'NATIONALITY': ''}
# {'NAME': 'IYAD NAZMI SALIH', 'NATIONALITY': 'Jordan'}
# {'NAME': 'ASHRAF MUHAMMAD YUSUF', 'NATIONALITY': 'Jordan'}
# {'NAME': 'FEREIDOUN ABBASI-DAVANI ', 'NATIONALITY': ''}
# {'NAME': 'ABDUL AZIZ ABBASIN ', 'NATIONALITY': ''}
# {'NAME': 'NASHWAN ABD AL-RAZZAQ ABD AL-BAQI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HUMAM ABD-AL-KHALIQ ABD-AL-GHAFUR', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ABD ALLAH MOHAMED RAGAB', 'NATIONALITY': 'Egypt'}
# {'NAME': 'AZIZIRAHMAN ABDUL AHAD ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL GHANI BARADAR ABDUL AHMAD TURK', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL QADEER BASIR ABDUL BASEER', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'NAZIR MOHAMMAD ABDUL BASIR ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MAJEED ABDUL CHAUDHRY ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'ABDUL GHAFAR QURISHI ABDUL GHANI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL SATAR ABDUL MANAN ', 'NATIONALITY': ''}
# {'NAME': 'ABDUL MANAN AGHA  ', 'NATIONALITY': ''}
# {'NAME': 'ABDUL HAI HAZEM ABDUL QADER', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'AHMAD TAHA KHALID ABDUL QADIR', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAYED ESMATULLAH ASEM ABDUL QUDDUS', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MUHAMMAD JIBRIL ABDUL RAHMAN', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'ALY SOLIMAN MASSOUD', 'NATIONALITY': 'Libya'}
# {'NAME': 'SHAMS UR-RAHMAN ABDUL ZAHIR', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'AMIR ABDULLAH ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUR REHMAN  ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'MAGHOMED MAGHOMEDZAKIROVICH ABDURAKHMANOV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'MOHAMAD IQBAL ABDURRAHMAN', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'ABDULPATTA ESCALON ABUBAKAR', 'NATIONALITY': 'Philippines'}
# {'NAME': 'ABDUL SAMAD ACHEKZAI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ADAM KHAN ACHEKZAI ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'MOCHAMMAD ACHWAN ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'NOURREDINE ADAM ', 'NATIONALITY': "['Central African Republic', 'Sudan']"}
# {'NAME': 'ABUKAR ALI ADAN', 'NATIONALITY': ''}
# {'NAME': 'AHMED AG ALBACHAR ', 'NATIONALITY': 'Mali'}
# {'NAME': 'HOUKA HOUKA AG ALHOUSSEINI', 'NATIONALITY': 'Mali'}
# {'NAME': 'IYAD AG GHALI ', 'NATIONALITY': 'Mali'}
# {'NAME': 'BAH AG MOUSSA ', 'NATIONALITY': 'Mali'}
# {'NAME': 'ABDUL RAHMAN AGHA ', 'NATIONALITY': "['Afghanistan', 'Pakistan']"}
# {'NAME': 'AHMAD ZIA AGHA', 'NATIONALITY': ''}
# {'NAME': 'JANAN AGHA ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAYED MOHAMMAD AZIM', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAYYED GHIASSOUDDINE AGHA ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'TOREK AGHA ', 'NATIONALITY': ''}
# {'NAME': 'AZIM AGHAJANI ', 'NATIONALITY': 'Iran (Islamic Republic of)'}
# {'NAME': 'FARHAD KANABI AHMAD', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MUHAMMAD YUNIS AHMAD', 'NATIONALITY': 'Iraq'}
# {'NAME': 'NAJMUDDIN FARAJ AHMAD', 'NATIONALITY': 'Iraq'}
# {'NAME': 'JABER ABDALLAH JABER', 'NATIONALITY': 'Kuwait'}
# {'NAME': 'MOHAMMAD AHMADI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ALI AKBAR AHMADIAN ', 'NATIONALITY': ''}
# {'NAME': 'ABUBAKER SHARIFF AHMED', 'NATIONALITY': ''}
# {'NAME': 'ADNAN S. HASAN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'TARIQ ANWAR EL SAYED', 'NATIONALITY': 'Egypt'}
# {'NAME': 'ZAKI EZAT ZAKI', 'NATIONALITY': 'Egypt'}
# {'NAME': 'AHMED JAN WAZIR AKHTAR MOHAMMAD', 'NATIONALITY': ''}
# {'NAME': 'SALEH MOHAMMAD KAKAR', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL BARI AKHUND ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ATTIQULLAH AKHUND ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD AMAN AKHUND', 'NATIONALITY': ''}
# {'NAME': 'MOHAMMAD HASSAN AKHUND', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD ABBAS AKHUND ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD ESSA AKHUND ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'AHMAD JAN AKHUNDZADA SHUKOOR', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'EHSANULLAH SARFIDA HESAMUDDIN', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD ESHAQ AKHUNZADA ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'DJAMEL AKKACHA ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'ABOU MOHAMED AL ADNANI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HAJJAJ BIN FAHD', 'NATIONALITY': 'Kuwait'}
# {'NAME': 'ABDUL MOHSEN ABDALLAH IBRAHIM', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'MOHAMMED AL GHABRA ', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'MOHAMMAD ALI AL HABBO', 'NATIONALITY': 'Syrian Arab Republic'}
# {'NAME': 'ABDULLAH YAHYA AL HAKIM', 'NATIONALITY': 'Yemen'}
# {'NAME': 'ABDELRAHMAN MOUHAMAD ZAFIR AL DABIDI', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'TAHA IBRAHIM ABDALLAH BAKR', 'NATIONALITY': 'Iraq'}
# {'NAME': 'AMID HUSAIN AL KUNI', 'NATIONALITY': ''}
# {'NAME': 'QUREN SALIH QUREN', 'NATIONALITY': ''}
# {'NAME': 'MUNIR AL QUBAYSI ', 'NATIONALITY': 'Iraq'}
# {'NAME': 'SALEH MESFER SALEH', 'NATIONALITY': 'Yemen'}
# {'NAME': 'AMRU AL-ABSI ', 'NATIONALITY': ''}
# {'NAME': 'SHAFI SULTAN MOHAMMED', 'NATIONALITY': 'Kuwait'}
# {'NAME': 'HAMID ABDALLAH AHMAD', 'NATIONALITY': 'Kuwait'}
# {'NAME': 'MEHREZ BEN MAHMOUD BEN SASSI', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'ABU UBAYDAH YUSUF AL-ANABI', 'NATIONALITY': 'Algeria'}
# {'NAME': 'ADIB SHABAN AL-ANI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MOHAMED BEN BELGACEM BEN ABDALLAH', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'IBRAHIM HASSAN TALI', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'ANWAR NASSER ABDULLA', 'NATIONALITY': "['United States of America', 'Yemeni']"}
# {'NAME': 'HIKMAT MIZBAN IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ABDULQADER MOHAMMED AL-BAGHDADI', 'NATIONALITY': ''}
# {'NAME': "IBRAHIM 'ISA HAJJI MUHAMMAD", 'NATIONALITY': 'Qatar'}
# {'NAME': 'SAFIA FARKASH AL-BARASSI', 'NATIONALITY': ''}
# {'NAME': 'SALEM NOR ELDIN AMOHAMED', 'NATIONALITY': 'Libya'}
# {'NAME': 'MUTHANNA HARITH AL-DARI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'NOUREDDINE BEN ALI BEN BELKASSEM', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'IZZAT IBRAHIM AL-DURI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'JAWHAR MAJID AL-DURI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ABD AL-AZIZ ADAY ZIMIN', 'NATIONALITY': ''}
# {'NAME': 'KHALID ABD AL-RAHMAN HAMD', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'MUHAMMAD ABD AL-KARIM AL-GHAMARI', 'NATIONALITY': 'Yemen'}
# {'NAME': 'OTHMAN AHMED OTHMAN', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'IBRAHIM SULEIMAN HAMAD', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'KAMAL BEN MAOELDI BEN HASSAN', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'AHMAD AL-HAMZI ', 'NATIONALITY': 'Yemen'}
# {'NAME': 'BASSAM AHMAD AL-HASRI', 'NATIONALITY': "['Syrian Arab Republic', 'State of Palestine']"}
# {'NAME': 'ABDULMALIK AL-HOUTHI ', 'NATIONALITY': ''}
# {'NAME': 'ABU MOHAMMED AL-JAWLANI ', 'NATIONALITY': 'Syrian Arab Republic'}
# {'NAME': 'TAHA YASSIN RAMADAN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MAYSAR ALI MUSA ABDALLAH', 'NATIONALITY': 'Iraq'}
# {'NAME': "SA'D BIN SA'D MUHAMMAD SHARIYAN", 'NATIONALITY': 'Qatar'}
# {'NAME': 'MUHAMMAD JAMAL ABD-AL RAHIM AHMAD', 'NATIONALITY': 'Egypt'}
# {'NAME': 'ABD AL-LATIF BIN ABDALLAH SALIH MUHAMMAD', 'NATIONALITY': 'Qatar'}
# {'NAME': 'MUHSIN KHADR AL-KHAFAJI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'UMAR MAHMUD IRHAYYIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HABIB BEN AHMED', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'TAREK BEN HABIB BEN AL-TOUMI', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'YUSUF AL-MADANI ', 'NATIONALITY': 'Yemen'}
# {'NAME': 'SALIM MUSTAFA MUHAMMAD', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MOTLAQ AMER AL-MARRANI', 'NATIONALITY': 'Yemen'}
# {'NAME': 'SAIF-AL-DIN AL-MASHHADANI ', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ABD-AL-HAMID AL-MASLI ', 'NATIONALITY': 'Libya'}
# {'NAME': 'AZZAM ABDULLAH ZUREIK', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'AKRAM TURKI HISHAN', 'NATIONALITY': ''}
# {'NAME': 'GHAZY FEZZA HISHAN', 'NATIONALITY': ''}
# {'NAME': 'KHAMIS SIRHAN AL-MUHAMMAD', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MUHANNAD AL-NAJDI ', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': '‘ABD AL-RAHMAN BIN ‘UMAYR AL-NU’AYMI', 'NATIONALITY': 'Qatar'}
# {'NAME': 'FAZEEL-A-TUL SHAYKH ABU MOHAMMED AMEEN', 'NATIONALITY': 'Afghan'}
# {'NAME': '‘ABD AL-RAHMAN MUHAMMAD MUSTAFA', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ASHRAF AL-QIZANI ', 'NATIONALITY': 'Tunisia'}
# {'NAME': "NIDAL AL-RABI'I ", 'NATIONALITY': 'Iraq'}
# {'NAME': 'AYAD FUTAYYIH KHALIFA', 'NATIONALITY': 'Iraq'}
# {'NAME': 'SAIF-AL-DIN FULAYYIH HASSAN TAHA', 'NATIONALITY': 'Iraq'}
# {'NAME': 'QASIM MOHAMED MAHDI', 'NATIONALITY': 'Yemen'}
# {'NAME': 'MU’TASSIM YAHYA ‘ALI', 'NATIONALITY': 'Yemen'}
# {'NAME': 'AMIR HAMUDI HASSAN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ADNAN ABOU WALID AL-SAHRAOUI', 'NATIONALITY': ''}
# {'NAME': 'MANSUR AL-SA’ADI ', 'NATIONALITY': 'Yemen'}
# {'NAME': 'ABDULLAH AL-SENUSSI ', 'NATIONALITY': ''}
# {'NAME': 'HAMAD AWAD DAHI SARHAN', 'NATIONALITY': 'Kuwait'}
# {'NAME': 'ALI MUSA AL-SHAWAKH ', 'NATIONALITY': 'Syrian Arab Republic'}
# {'NAME': 'HASAN AL-SALAHAYN SALIH', 'NATIONALITY': 'Libya'}
# {'NAME': 'SULTAN HASHIM AHMAD', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ABID HAMID MAHMUD', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ALI HASSAN AL-MAJID', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ALI SADDAM HUSSEIN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'BARZAN ABD AL-GHAFUR SULAIMAN MAJID', 'NATIONALITY': 'Iraq'}
# {'NAME': 'BARZAN IBRAHIM HASSAN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HALA SADDAM HUSSEIN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HAMID RAJA SHALAH', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HANI ABD-AL-LATIF TILFAH', 'NATIONALITY': 'Iraq'}
# {'NAME': 'IBRAHIM AHMAD ABD AL-SATTAR MUHAMMED', 'NATIONALITY': 'Iraq'}
# {'NAME': 'JAMAL MUSTAFA ABDALLAH SULTAN', 'NATIONALITY': 'Iraq'}
# {'NAME': "MUZAHIM SA'B HASSAN", 'NATIONALITY': 'Iraq'}
# {'NAME': 'QUSAY SADDAM HUSSEIN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'RAFI ABD-AL-LATIF TILFAH', 'NATIONALITY': 'Iraq'}
# {'NAME': 'RAGHAD SADDAM HUSSEIN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'RANA SADDAM HUSSEIN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'RUKAN RAZUKI ABD-AL-GHAFUR SULAIMAN', 'NATIONALITY': 'Iraq'}
# {'NAME': "SA'D ABD-AL-MAJID AL-FAISAL", 'NATIONALITY': 'Iraq'}
# {'NAME': "SAB'AWI IBRAHIM HASSAN", 'NATIONALITY': 'Iraq'}
# {'NAME': 'SADDAM HUSSEIN AL-TIKRITI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'TAHIR JALIL HABBUSH', 'NATIONALITY': 'Iraq'}
# {'NAME': 'UDAY SADDAM HUSSEIN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'WALID HAMID TAWFIQ', 'NATIONALITY': 'Iraq'}
# {'NAME': 'WATBAN IBRAHIM HASSAN', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HASSAN ABDULLAH HERSI', 'NATIONALITY': 'Somalia'}
# {'NAME': 'GHAZI HAMMUD AL-UBAIDI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'YAHIA ABDALLAH AL-UBAIDI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'INTISSAR AL-UBAYDI ', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MAHFOUZ OULD AL-WALID', 'NATIONALITY': 'Mauritania'}
# {'NAME': 'AHMED ABDULLAH SALEH AL-KHAZMARI', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'FAYSAL AHMAD BIN ALI', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'GHALIB ABDULLAH AL-ZAIDI', 'NATIONALITY': 'Yemen'}
# {'NAME': 'AIMAN MUHAMMED RABI', 'NATIONALITY': 'Egypt'}
# {'NAME': 'ABD-AL-MAJID AZIZ AL-ZINDANI', 'NATIONALITY': 'Yemen'}
# {'NAME': 'UGLA ABID SAKR', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HAMID HAMAD HAMID', 'NATIONALITY': 'Kuwait'}
# {'NAME': '‘ABD AL-RAHMAN KHALAF ‘UBAYD JUDAY’', 'NATIONALITY': 'Kuwait'}
# {'NAME': 'SULAIMAN JASSEM SULAIMAN', 'NATIONALITY': 'Kuwaiti citizenship withdrawn in 2002'}
# {'NAME': 'IBRAHIM AWWAD IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MATI UR-REHMAN ALI MUHAMMAD ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'ABDUL HABIB ALIZAI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'TARAD MOHAMMAD Alnori Alfares', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'HAMDULLAH ALLAH NOOR ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MUSA HILAL ABDALLA', 'NATIONALITY': 'Sudan'}
# {'NAME': 'ISAM ALI MOHAMED', 'NATIONALITY': 'Jordan'}
# {'NAME': 'MOHAMMED MASOOD AZHAR', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'MOHAMMAD SADIQ AMIR MOHAMMAD ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAIFI AMMARI ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'HUDA SALIH MAHDI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'PAUL MALONG AWAN', 'NATIONALITY': "['South Sudan', 'Uganda']"}
# {'NAME': 'ABDULLAH ANSHORI ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'MUHAMMAD TAHER ANWARI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAID ARIF ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'RUSTAM MAGOMEDOVICH ASELDEROV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'MUHSIN FADHIL AYED', 'NATIONALITY': 'Kuwait'}
# {'NAME': 'HAJI MUHAMMAD ASHRAF', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'ISLAM SEIT-UMAROVICH ATABIEV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'AHMED ABDI AW-MOHAMED', 'NATIONALITY': 'Somalia'}
# {'NAME': 'ABDUL BAQI BASIR AWAL SHAH', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'HASSAN DAHIR AWEYS', 'NATIONALITY': 'Somalia'}
# {'NAME': 'HASSAN DAHIR AWEYS', 'NATIONALITY': 'Somalia'}
# {'NAME': 'RICARDO PEREZ AYERAS', 'NATIONALITY': 'Philippines'}
# {'NAME': 'MAALIM AYMAN ', 'NATIONALITY': ''}
# {'NAME': 'MOHAMMAD RASUL AYYUB ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'TARIQ AZIZ ', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ABD AL-BASET AZZOUZ ', 'NATIONALITY': 'Libya'}
# {'NAME': 'Sundus Abd Al-Ghafur ', 'NATIONALITY': 'Iraq'}
# {'NAME': 'Fitiwi Abdelrazak ', 'NATIONALITY': 'Eritrea'}
# {'NAME': 'Abdifatah Abubakar Abdi', 'NATIONALITY': 'Somalia'}
# {'NAME': 'Ermias Alem ', 'NATIONALITY': 'Eritrea'}
# {'NAME': 'Ahmad Iman Ali', 'NATIONALITY': 'Kenya'}
# {'NAME': 'Muhammad Bahrum Naim', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'Ahmoudou Ag Asriw', 'NATIONALITY': 'Mali'}
# {'NAME': 'ABDUL ROSYID RIDHO', 'NATIONALITY': 'Indonesia'}
# {'NAME': "ABU BAKAR BA'ASYIR ", 'NATIONALITY': 'Indonesia'}
# {'NAME': "ABDUL RAHIM BA'AYSIR ", 'NATIONALITY': 'Indonesia'}
# {'NAME': 'ERIC BADEGE ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'SAID BAHAJI ', 'NATIONALITY': "['Germany', 'Morocco']"}
# {'NAME': 'MAHMOUD MOHAMMAD AHMED', 'NATIONALITY': 'Saudi Arabia'}
# {'NAME': 'BAHMANYAR MORTEZA BAHMANYAR ', 'NATIONALITY': 'Iran'}
# {'NAME': 'SEKA BALUKU ', 'NATIONALITY': 'Uganda'}
# {'NAME': 'AYYUB BASHIR ', 'NATIONALITY': "['Uzbekistan', 'Afghanistan']"}
# {'NAME': 'MAHMOOD SULTAN BASHIR-UD-DIN', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'TARKHAN TAYUMURAZOVICH BATIRASHVILI', 'NATIONALITY': 'Georgia'}
# {'NAME': 'MOHAMED BELKALEM ', 'NATIONALITY': 'Algerian'}
# {'NAME': 'MOKHTAR BELMOKHTAR ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'BOUBAKER BEN HABIB BEN AL-HAKIM', 'NATIONALITY': "['France', 'Tunisia']"}
# {'NAME': 'MAHRI SIDI AMAR', 'NATIONALITY': 'Mali'}
# {'NAME': 'SOFIANE BEN GOUMO ', 'NATIONALITY': 'Libya'}
# {'NAME': 'SEIFALLAH BEN OMAR BEN MOHAMED', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'MOUNIR BEN DHAOU BEN BRAHIM', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'SALIM BENGHALEM ', 'NATIONALITY': 'France'}
# {'NAME': 'HAFIZ ABDUL SALAM BHUTTAVI', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'HAMZA USAMA MUHAMMAD', 'NATIONALITY': ''}
# {'NAME': 'BILAL BIN MARWAN ', 'NATIONALITY': ''}
# {'NAME': 'MOHAMAD RAFI BIN UDIN', 'NATIONALITY': "['Malaysia', 'Indonesia']"}
# {'NAME': 'RAMZI MOHAMED ABDULLAH', 'NATIONALITY': 'Yemen'}
# {'NAME': 'JANG BOM SU ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'PAK BONG NAM ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'FAYCAL BOUGHANEMI ', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'BOUBEKEUR BOULGHITI ', 'NATIONALITY': "['Algeria', 'Palestinian']"}
# {'NAME': 'HAMADI BEN ABDUL AZIZ BEN ALI', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'FRANÇOIS YANGOUVONDA BOZIZÉ', 'NATIONALITY': "['Central African Republic', 'South Sudan']"}
# {'NAME': 'FRANK KAKOLELE BWAMBALE ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'MIN BYONG CHOL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'ASLAN AVGAZAROVICH BYUTUKAEV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'Salah Badi ', 'NATIONALITY': ''}
# {'NAME': 'Malik Ruslanovich Barkhanoev', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'Yasin Ali Baynah', 'NATIONALITY': "['Somalia', 'Sweden']"}
# {'NAME': 'IBRAIMA CAMARÁ ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': "KO CH'O'L-CHAE ", 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'PAEK CHANG-HO ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'AKHMED RAJAPOVICH CHATAEV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'AAMIR ALI CHAUDHRY', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'YASSINE CHEKKOURI ', 'NATIONALITY': 'Morocco'}
# {'NAME': 'PETER CHERIF ', 'NATIONALITY': 'France'}
# {'NAME': "YO'N CHO'NG NAM ", 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': "MUN CHO'NG-CH'O'L ", 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KO CHOL MAN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM CHOL NAM ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'JO CHOL SONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KANG CHOL SU ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'YU CHOL U ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'ANJEM CHOUDARY ', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'MONIR CHOUKA ', 'NATIONALITY': "['Germany', 'Morocco']"}
# {'NAME': 'YASSIN CHOUKA ', 'NATIONALITY': "['Germany', 'Morocco']"}
# {'NAME': 'RI CHUN HWAN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'RI CHUN SONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'CHOE CHUN YONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'CHOE CHUN-SIK ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'JAMES KOANG CHUOL', 'NATIONALITY': 'South Sudan'}
# {'NAME': 'MAXAMED CABDULLAAH CIISE', 'NATIONALITY': 'Somalia'}
# {'NAME': 'SHANE DOMINIC CRAWFORD', 'NATIONALITY': 'Trinidad and Tobago'}
# {'NAME': 'Jimmy Cherizier ', 'NATIONALITY': ''}
# {'NAME': 'ANDERS CAMEROON OSTENSVIG', 'NATIONALITY': 'Norway'}
# {'NAME': 'CRANHA DANFA ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'ALI DARASSA ', 'NATIONALITY': 'Central African Republic'}
# {'NAME': 'AHMAD VAHID DASTJERDI ', 'NATIONALITY': ''}
# {'NAME': 'PIO ABOGNE DE VERA', 'NATIONALITY': 'Philippines'}
# {'NAME': 'AHMED DEGHDEGH ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'SHAHABUDDIN DELAWAR ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'REDENDO CAIN DELLOSA', 'NATIONALITY': 'Philippines'}
# {'NAME': 'FELICIANO SEMBORIO DELOS REYES JR.', 'NATIONALITY': 'Philippines'}
# {'NAME': 'AHMAD DERAKHSHANDEH ', 'NATIONALITY': ''}
# {'NAME': 'OUMAR DIABY ', 'NATIONALITY': 'Senegal'}
# {'NAME': 'ABDULQADER YUSEF DIBRI', 'NATIONALITY': ''}
# {'NAME': 'AHMED DIRIYE ', 'NATIONALITY': ''}
# {'NAME': 'IDRISSA DJALÓ ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'KAMEL DJERMANE ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'YAHIA DJOUADI ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'ABU ZAYD UMAR', 'NATIONALITY': ''}
# {'NAME': 'DOST MOHAMMAD  ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'NIK MOHAMMAD DOST MOHAMMAD ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDELMALEK DROUKDEL ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'SIMON GATWECH DUAL', 'NATIONALITY': ''}
# {'NAME': 'LIONEL DUMONT ', 'NATIONALITY': 'France'}
# {'NAME': 'AGUS DWIKARNA ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'ABDULLAH AHMED ABDULLAH', 'NATIONALITY': 'Egypt'}
# {'NAME': 'RADI ABD EL SAMIE ABOU EL YAZID', 'NATIONALITY': 'Egypt'}
# {'NAME': 'REDOUANE EL HABHAB ', 'NATIONALITY': "['Germany', 'Morocco']"}
# {'NAME': 'MOUNIR EL MOTASSADEQ ', 'NATIONALITY': 'Morocco'}
# {'NAME': 'ABD EL KADER MAHMOUD MOHAMED', 'NATIONALITY': 'Egypt'}
# {'NAME': 'ELSHAFEE EL SHEIKH ', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'GAFFAR MOHAMMED ELHASSAN', 'NATIONALITY': 'na'}
# {'NAME': 'MOHAMMAD AZAM ELMI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAMI BEN KHAMIS BEN SALEH', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'MOHAMMAD ESLAMI ', 'NATIONALITY': ''}
# {'NAME': 'REZA-GHOLI ESMAELI ', 'NATIONALITY': ''}
# {'NAME': 'MOUSSA BEN OMAR BEN ALI', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'ZAKARYA ESSABAR ', 'NATIONALITY': 'Morocco'}
# {'NAME': 'FAIZ  ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHSEN FAKHRIZADEH-MAHABADI ', 'NATIONALITY': ''}
# {'NAME': 'MOHAMMAD SHAFIQULLAH AHMADI FATIH KHAN', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MAULANA FAZLULLAH ', 'NATIONALITY': ''}
# {'NAME': 'PETER GADET ', 'NATIONALITY': ''}
# {'NAME': 'SALAH EDDINE GASMI ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'HAROUN GAYE ', 'NATIONALITY': ''}
# {'NAME': 'TARKHAN ISMAILOVICH GAZIEV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'SANAULLAH GHAFARI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'AHMED KHALFAN GHAILANI', 'NATIONALITY': 'United Republic of Tanzania'}
# {'NAME': 'NAYIF SHINDAKH THAMIR', 'NATIONALITY': 'Iraq'}
# {'NAME': 'FADIL MAHMUD GHARIB', 'NATIONALITY': 'Iraq'}
# {'NAME': 'AREFULLAH AREF GHAZI MOHAMMAD', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'AMOR MOHAMED GHEDEIR', 'NATIONALITY': 'Algeria'}
# {'NAME': 'MOHAMMED OMAR GHULAM NABI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ZAURBEK SALIMOVICH GUCHAEV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'KEVIN JORDAN AXEL', 'NATIONALITY': 'France'}
# {'NAME': 'BAKHT GUL ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'GUN GUN RUSMAN GUNAWAN', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'RUSTUM HANAFI HABIBULLAH', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MIZBAN KHADR HADI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'GUL AHMAD HAKIMI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SALIM AHMAD SALIM', 'NATIONALITY': 'Yemen'}
# {'NAME': 'ADEL BEN AL-AZHAR BEN YOUSSEF', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'OMAR HAMMAMI ', 'NATIONALITY': 'United States. Also believed to hold Syrian nationality'}
# {'NAME': 'PAK HAN SE ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'DIN MOHAMMAD HANIF ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ISNILON TOTONI HAPILON', 'NATIONALITY': 'Philippines'}
# {'NAME': 'ABDUL HAQ ', 'NATIONALITY': 'China'}
# {'NAME': 'JALALUDDIN HAQQANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'KHALIL AHMED HAQQANI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD SALIM HAQQANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'NASIRUDDIN HAQQANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAYYED MOHAMMED HAQQANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SIRAJUDDIN JALLALOUDINE HAQQANI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'YAHYA HAQQANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ALI BARZAN IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'AYMAN SABAWI IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'BASHAR SABAWI IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'IBRAHIM SABAWI IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'KHAWLA BARZAN IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MOHAMMAD BARZAN IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'NOOR BARZAN IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'OMAR SABAWI IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'SAJA BARZAN IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'SA’D SABAWI IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'THORAYA BARZAN IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'YASIR SABAWI IBRAHIM', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MAXIME HAUCHARD ', 'NATIONALITY': 'France'}
# {'NAME': 'MOHAMMAD HEJAZI ', 'NATIONALITY': ''}
# {'NAME': 'HIDAYATULLAH  ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'NAJIBULLAH HAQQANI HIDAYATULLAH', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'RAED MUHAMMAD HASAN MUHAMMAD', 'NATIONALITY': "['Jordan', 'United States of America']"}
# {'NAME': 'ABDOULAYE HISSENE ', 'NATIONALITY': "['Central African Republic', 'Chad']"}
# {'NAME': 'YUN HO-JIN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'MOHSEN HOJATI ', 'NATIONALITY': ''}
# {'NAME': 'RI HONG-SOP ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'ABDUL RAHMAN AHMAD HOTTAK', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'OMAR ALI HUSSAIN', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'MOHAMMAD TAHIR HAMMID', 'NATIONALITY': 'Iraq'}
# {'NAME': 'ABD-AL-TAWWAB MULLAH HUWAYSH', 'NATIONALITY': 'Iraq'}
# {'NAME': 'CHOE HWI ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'CHU HYO’K ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'MOSTAFA KAMEL MOSTAFA', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'MUHAMMAD SHOLEH IBRAHIM', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'JAN MOHAMMAD MADANI IKRAM', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'PAK CHUN IL', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'CHO IL U ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'NUSRET IMAMOVIC ', 'NATIONALITY': 'Bosnia and Herzegovina'}
# {'NAME': 'ANTÓNIO INJAI ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'ZAFAR IQBAL ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'NURJAMAN RIDUAN ISAMUDDIN', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'GUL AGHA ISHAKZAI', 'NATIONALITY': ''}
# {'NAME': 'SHAMIL MAGOMEDOVICH ISMAILOV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'GASTON IYAMUREMYE ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'Osama Al Kuni Ibrahim', 'NATIONALITY': 'Libya'}
# {'NAME': 'Pak Il Kyu ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KU JA HYONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'ABU BAKR YUNIS', 'NATIONALITY': ''}
# {'NAME': 'RI JAE IL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'QUDRATULLAH JAMAL ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAIDULLAH JAN ', 'NATIONALITY': ''}
# {'NAME': 'HAN JANG SU ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'RI JE-SON ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'RYU JIN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'SALLY-ANNE FRANCES JONES', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'KIM JONG SIK ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'HUSAYN JUAYTHINI ', 'NATIONALITY': 'Palestinian'}
# {'NAME': 'SALIM Y SALAMUDDIN JULKIPLI ', 'NATIONALITY': 'Philippines'}
# {'NAME': 'KIM JUNG JONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'Ibrahim Saeed Salim', 'NATIONALITY': 'Libya'}
# {'NAME': 'INNOCENT KAINA ', 'NATIONALITY': ''}
# {'NAME': 'RAHMATULLAH KAKAZADA ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'JÉRÔME KAKWAVU BUKANDE ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'MEHDI BEN MOHAMED BEN MOHAMED', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'GÉDÉON KYUNGU MUTANGA WA BAFUNKWA', 'NATIONALITY': ''}
# {'NAME': 'MOHAMMED YUSIP KARIM', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'DAWOOD IBRAHIM KASKAR', 'NATIONALITY': 'India'}
# {'NAME': 'GERMAIN KATANGA ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'MEHRDADA AKHLAGHI KETABACHI ', 'NATIONALITY': ''}
# {'NAME': 'ABDUL RAUF KHADEM ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'KHAIRULLAH KHAIRKHWAH ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'FUAD MOHAMED KHALAF', 'NATIONALITY': 'Somali'}
# {'NAME': 'GULMUROD KHALIMOV ', 'NATIONALITY': 'Tajikistan'}
# {'NAME': 'MUSTAFA HAJJI MUHAMMAD', 'NATIONALITY': "['Pakistan', 'Saudi Arabian']"}
# {'NAME': 'EZATULLAH HAQQANI KHAN SAYYID', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ANAS HASAN KHATTAB', 'NATIONALITY': 'Syrian Arab Republic'}
# {'NAME': 'KHAIRULLAH BARAKZAI KHUDAI NAZAR', 'NATIONALITY': ''}
# {'NAME': 'MOHAMMED QASIM MIR WALI KHUDAI RAHIM', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD NAIM BARICH KHUDAIDAD', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MUHAMMED REZA LAHAMAN', 'NATIONALITY': 'Philippines'}
# {'NAME': 'EMILIE EDWIGE KONIG', 'NATIONALITY': 'France'}
# {'NAME': 'ALI KONY ', 'NATIONALITY': ''}
# {'NAME': 'JOSEPH KONY ', 'NATIONALITY': 'Uganda'}
# {'NAME': 'SALIM KONY ', 'NATIONALITY': ''}
# {'NAME': 'ALEXANDA AMON KOTEY', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'AMADOU KOUFA ', 'NATIONALITY': ''}
# {'NAME': 'MARTIN KOUMTAMADJI ', 'NATIONALITY': "['Chad', 'Central African Republic', 'Congo']"}
# {'NAME': 'HYON KWANG IL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM KWANG-IL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': "RA KY'ONG-SU ", 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'MUN KYONG HWAN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM KYONG IL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM KYONG OK ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM KYU ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'Mohammed Al Amin Al-Arabi', 'NATIONALITY': 'Libya'}
# {'NAME': 'Rashid Taan Kathim', 'NATIONALITY': 'Iraq'}
# {'NAME': 'MORAD LAABOUDI ', 'NATIONALITY': 'Morocco'}
# {'NAME': 'ABDELKADER LAAGOUB ', 'NATIONALITY': 'Morocco'}
# {'NAME': 'MOHAMED LAHBOUS ', 'NATIONALITY': 'Mali'}
# {'NAME': 'MOHAMED LAKHAL ', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'ZAKI-UR-REHMAN LAKHVI ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'ABDUL RAZAQ AKHUND LALA AKHUND', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'RUBEN PESTANO LAVILLA, JR', 'NATIONALITY': 'Philippines'}
# {'NAME': 'DJAMEL LOUNICI ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'THOMAS LUBANGA ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': "TAHA MUHYI-AL-DIN MA'RUF", 'NATIONALITY': 'Iraq'}
# {'NAME': 'MYRNA AJIJUL MABANZA', 'NATIONALITY': 'Philippines'}
# {'NAME': 'ZIA-UR-RAHMAN MADANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'BASHIR MOHAMED MAHAMOUD', 'NATIONALITY': 'Somalia'}
# {'NAME': 'ADIL ABDALLAH MAHDI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'AQSA MAHMOOD ', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'MOHAMED BEN AHMED', 'NATIONALITY': 'Mali'}
# {'NAME': 'SULTANI MAKENGA ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'GABRIEL JOK RIAK MAKOL', 'NATIONALITY': 'South Sudan'}
# {'NAME': 'NASER MALEKI ', 'NATIONALITY': ''}
# {'NAME': 'RI MAN GON ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': "FARES MOHAMMED MANA'A", 'NATIONALITY': ''}
# {'NAME': 'KHAWA PANGA MANDRO ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'MARIAL CHANUONG YOL', 'NATIONALITY': 'South Sudan'}
# {'NAME': 'ABDUL LATIF MANSUR ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMED OULD MATALY', 'NATIONALITY': 'Mali'}
# {'NAME': 'MOHAMMADULLAH MATI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ALLAH DAD MATIN ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MATIULLAH  ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MATUQ MOHAMMED MATUQ', 'NATIONALITY': ''}
# {'NAME': 'ALI MAYCHOU ', 'NATIONALITY': 'Morocco'}
# {'NAME': 'JIBRIL ABDULKARIM IBRAHIM', 'NATIONALITY': 'Sudanese by birth'}
# {'NAME': 'ABDUL QUDDUS MAZHARI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'FAZL MOHAMMAD MAZLOOM ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'CALLIXTE MBARUSHIMANA ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'MOHAMMAD WALI MOHAMMAD EWAZ ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL MANAN MOHAMMAD ISHAK ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL KABIR MOHAMMAD JAN ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDULLAH HAMAD MOHAMMAD KARIM', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD SARWAR SIDDIQMAL', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD YAQOUB  ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD SHAFIQ MOHAMMADI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABOUD ROGO MOHAMMED', 'NATIONALITY': ''}
# {'NAME': 'YUNOS UMPARA MOKLIS', 'NATIONALITY': 'Philippines'}
# {'NAME': 'MOHAMED AMIN MOSTAFA', 'NATIONALITY': 'Iraq'}
# {'NAME': 'AMIR KHAN MOTAQI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDULHAI MOTMAEN ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'DJAMEL MOUSTFA ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'IRUTA DOUGLAS MPAMO ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'MUBARAK MUSHAKHAS SANAD', 'NATIONALITY': 'Kuwait'}
# {'NAME': 'SYLVESTRE MUDACUMURA ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'LEODOMIR MUGARAGU ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'ALLAH DAD TAYEB WALI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'NAJIBULLAH MUHAMMAD JUMA ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD MOSLIM HAQQANI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMED YAHYA MUJAHID', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'LEOPOLD MUJYAMBERE ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'JAMIL MUKULU ', 'NATIONALITY': 'Uganda'}
# {'NAME': 'KIM MUN CHOL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'PAK MUN IL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KANG MUN KIL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'ARIS MUNANDAR ', 'NATIONALITY': 'Indonesia (as at Dec. 2003)'}
# {'NAME': 'MUHINDO AKILI MUNDOS', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'ABDUL HAKIM MURAD ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'IGNACE MURWANASHYAKA ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'STRATON MUSONI ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'ALI SAYYID MUHAMED', 'NATIONALITY': 'Egypt'}
# {'NAME': 'JULES MUTEBUTSI ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'ASEEL MUTHANA ', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'NASSER AHMED MUTHANA', 'NATIONALITY': 'United Kingdom of Great Britain and Northern Ireland'}
# {'NAME': 'GUIDON SHIMIRAY MWISSA', 'NATIONALITY': ''}
# {'NAME': 'JON MYONG GUK ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'CHANG MYONG-CHIN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'Murad Iraklievich Margoshvili', 'NATIONALITY': "['Russian Federation', 'Georgia']"}
# {'NAME': 'Noor Wali Mehsud', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'Mohamed Ousmane Ag', 'NATIONALITY': 'Mali'}
# {'NAME': 'TCHIPA NA BIDON ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'TCHAM NA MAN ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'ESTÊVÃO NA MENA ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'TAYEB NAIL ', 'NATIONALITY': 'Algeria'}
# {'NAME': 'KIM NAM UNG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'MOHAMMAD REZA NAQDI ', 'NATIONALITY': ''}
# {'NAME': 'DABA NAUALNA ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'MOHAMMAD MEHDI NEJAD NOURI ', 'NATIONALITY': ''}
# {'NAME': 'BAUDOIN NGARUYE WA MYAMURO ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'EUGÈNE BARRET NGAÏKOSSET', 'NATIONALITY': ''}
# {'NAME': 'MATHIEU, CHUI NGUDJOLO ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'JÚLIO NHATE ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'FLORIBERT NGABU NJABU ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'LAURENT NKUNDA ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'HAMDULLAH NOMANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD ALEEM NOORANI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL BASIR NOORZAI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MALIK NOORZAI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'FELICIEN NSANZUBUKIRE ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'PACIFIQUE NTAWUNGUKA ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'NURULLAH NURI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'JAMES NYAKUNI ', 'NATIONALITY': 'Uganda'}
# {'NAME': 'ABDUL MANAN NYAZI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'LUCIEN NZAMBAMWITA ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'STANISLAS NZEYIMANA ', 'NATIONALITY': 'Rwanda'}
# {'NAME': 'AHMED SHAH NOORZAI OBAIDULLAH', 'NATIONALITY': ''}
# {'NAME': 'HASSAN MAHAT OMAR', 'NATIONALITY': 'Possibly Ethiopian'}
# {'NAME': 'ABDUL JABBAR OMARI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD IBRAHIM OMARI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDERRAHMANE OULD EL AMAR ', 'NATIONALITY': 'Mali'}
# {'NAME': 'HAMADA OULD MOHAMED EL KHAIRY ', 'NATIONALITY': "['Mauritania', 'Mali']"}
# {'NAME': 'ABD AL-RAHMAN OULD MUHAMMAD AL-HUSAYN OULD MUHAMMAD SALIM', 'NATIONALITY': 'Mauritania'}
# {'NAME': 'ALI BEN TAHER BEN FALEH', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'TARAK BEN TAHER BEN FALEH', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'DIEUDONNÉ OZIA MAZIO ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'Mus’ab Mustafa Abu al Qassim', 'NATIONALITY': 'Libya'}
# {'NAME': 'SHER MOHAMMAD ABBAS STANEKZAI PADSHAH KHAN', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'DINNO AMOR ROSALEJOS PAREJA', 'NATIONALITY': 'Philippines'}
# {'NAME': 'UMAR PATEK ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'ANGGA DIMAS PERSHADA', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'RI PYONG CHUL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'SAYYID MOHAMMED QADHAF AL-DAM', 'NATIONALITY': ''}
# {'NAME': 'AISHA MUAMMAR MUHAMMED ABU MINYAR', 'NATIONALITY': ''}
# {'NAME': 'HANNIBAL MUAMMAR QADHAFI', 'NATIONALITY': ''}
# {'NAME': 'KHAMIS MUAMMAR QADHAFI', 'NATIONALITY': ''}
# {'NAME': 'MOHAMMED MUAMMAR QADHAFI', 'NATIONALITY': ''}
# {'NAME': 'MUAMMAR MOHAMMED ABU MINYAR', 'NATIONALITY': ''}
# {'NAME': 'MUTASSIM QADHAFI ', 'NATIONALITY': ''}
# {'NAME': 'SAADI QADHAFI ', 'NATIONALITY': ''}
# {'NAME': 'SAIF AL-ARAB QADHAFI ', 'NATIONALITY': ''}
# {'NAME': 'SAIF AL-ISLAM QADHAFI ', 'NATIONALITY': ''}
# {'NAME': 'NOORUDDIN TURABI MUHAMMAD', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ARIF QASMANI ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'AMINULLAH AMIN QUDDUS', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL SALAM HANAFI ALI MARDAN', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'FAZL RABI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ALI MOHAMED RAGE', 'NATIONALITY': 'Somalia'}
# {'NAME': 'FAZAL RAHIM ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'YAR MOHAMMAD RAHIMI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD HASAN RAHMANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDELHALIM HAFED ABDELFATTAH', 'NATIONALITY': 'Algeria'}
# {'NAME': 'MALEK REUBEN RIAK', 'NATIONALITY': 'South Sudan'}
# {'NAME': 'HABIBULLAH RESHAD ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MORTEZA REZAIE ', 'NATIONALITY': ''}
# {'NAME': 'TAUFIK RIFKI ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'OMAN ROCHMAN ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'AL-AZHAR BEN KHALIFA BEN AHMED', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'JEAN-MARIE LUGERERO RUNIGA ', 'NATIONALITY': ''}
# {'NAME': 'ABU RUSDAN ', 'NATIONALITY': ''}
# {'NAME': 'KANG RYONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'Mahamadou Ag Rhissa', 'NATIONALITY': 'Mali'}
# {'NAME': 'FARED SAAL ', 'NATIONALITY': "['Germany', 'Algeria']"}
# {'NAME': 'AMIN MUHAMMAD UL HAQ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD HAMDI MOHAMMAD', 'NATIONALITY': 'Yemen'}
# {'NAME': 'HAFIZ MUHAMMAD SAEED', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'MORTEZA SAFARI ', 'NATIONALITY': ''}
# {'NAME': 'YAHYA RAHIM SAFAVI ', 'NATIONALITY': ''}
# {'NAME': 'RADULAN SAHIRON ', 'NATIONALITY': 'Philippines'}
# {'NAME': 'NESSIM BEN ROMDHANE SAHRAOUI', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'AHMED ALI ABDULLAH', 'NATIONALITY': 'Yemen'}
# {'NAME': 'ALI ABDULLAH SALEH', 'NATIONALITY': 'Yemen'}
# {'NAME': 'MOHAMMED ABDEL-HALIM HEMAIDA', 'NATIONALITY': 'Egypt'}
# {'NAME': 'ABDULHAI SALEK ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'HOSEIN SALIMI ', 'NATIONALITY': ''}
# {'NAME': 'MAALIM SALMAN ', 'NATIONALITY': ''}
# {'NAME': 'HILARION DEL ROSARIO SANTOS', 'NATIONALITY': 'Philippines'}
# {'NAME': 'WIJI JOKO SANTOSO', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'NOOR MOHAMMAD SAQIB ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SADUDDIN SAYYED ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'PAEK SE BONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'ABDUL WALI SEDDIQI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL WAHED SHAFIQ ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'AKHTAR MOHAMMAD MANSOUR', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'RAHMATULLAH SHAH NAWAZ ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAMIRA SHAHBANDAR ', 'NATIONALITY': 'Iraq'}
# {'NAME': 'SAID AHMED SHAHIDKHEL ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SHAMSUDDIN  ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'NTABO NTABERI SHEKA ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'ABUBAKAR MOHAMMED SHEKAU', 'NATIONALITY': 'Nigeria'}
# {'NAME': 'HAMIDULLAH AKHUND SHER MOHAMMAD', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'THARWAT SALAH SHIHATA', 'NATIONALITY': 'Egypt'}
# {'NAME': 'ABDUL GHAFAR SHINWARI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'PARLINDUNGAN SIREGAR ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'ROODI SLEWA ', 'NATIONALITY': 'Iraq'}
# {'NAME': 'HWANG SOK-HWA ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'QASEM SOLEIMANI ', 'NATIONALITY': ''}
# {'NAME': 'JANG SONG CHOL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'RI SONG HYOK ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'CHOE SONG IL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'BI SIDI SOULEMAN ', 'NATIONALITY': 'Central African Republic'}
# {'NAME': 'HABIB SOUSSOU ', 'NATIONALITY': 'Central African Republic'}
# {'NAME': "CH'OE SO’K MIN ", 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'RI SU YONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'YAZID SUFAAT ', 'NATIONALITY': 'Malaysia'}
# {'NAME': 'BAMBANG SUKIRNO ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'ARIS SUMARSONO ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'HAMDULLAH SUNANI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'JANG SUNG NAM ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'YASSIN SYAWAL ', 'NATIONALITY': 'Indonesia'}
# {'NAME': 'ALI AKBAR TABATABAEI ', 'NATIONALITY': 'Iran (Islamic Republic of)'}
# {'NAME': 'KO TAE HUN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'BOSCO TAGANDA ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'ABDUL RAQIB TAKHARI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'IBRAHIM ALI ABU BAKR', 'NATIONALITY': 'Libya'}
# {'NAME': 'SAJIDA KHAYRALLAH TILFAH', 'NATIONALITY': 'Iraq'}
# {'NAME': 'PAK TO CHUN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'QARI SAIFULLAH TOKHI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'KIM TONG CHOL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM TONG MY’ONG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM TONG-HO ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'ANGELO RAMIREZ TRINIDAD', 'NATIONALITY': 'Philippines'}
# {'NAME': 'MOHAMMED TUFAIL ', 'NATIONALITY': 'Pakistan'}
# {'NAME': 'MAMADU TURE ', 'NATIONALITY': 'Guinea-Bissau'}
# {'NAME': 'DOKU KHAMATOVICH UMAROV', 'NATIONALITY': "['Russian Federation', 'USSR (until 1991)']"}
# {'NAME': 'OMAR MAHMOUD UTHMAN', 'NATIONALITY': 'Jordan'}
# {'NAME': 'RI U’N SO’NG ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'AYRAT NASIMOVICH VAKHITOV', 'NATIONALITY': 'Russian Federation'}
# {'NAME': 'ABDUL JALIL HAQQANI WALI MOHAMMAD', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ATIQULLAH WALI MOHAMMAD ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'WALIJAN  ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'NAZIRULLAH HANAFI WALIULLAH', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL-HAQ WASSIQ ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'AHMED JAN AKHUNDZADA WAZIR', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD JAWAD WAZIRI ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SANTINO DENG WOL', 'NATIONALITY': ''}
# {'NAME': 'PAE WON UK ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'UBAIDULLAH AKHUND YAR MOHAMMAD AKHUND', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL RAHMAN YASIN ', 'NATIONALITY': 'United States of America'}
# {'NAME': 'ALFRED YEKATOM ', 'NATIONALITY': 'Central African Republic'}
# {'NAME': 'ADEM YILMAZ ', 'NATIONALITY': 'Turkey'}
# {'NAME': 'CHO YON CHUN ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'KIM YONG CHOL ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'RI YONG MU ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'PAK YONG SIK ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'JANG YONG SON ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'JO YONG-WON ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'OUMAR YOUNOUS ABDOULAY ', 'NATIONALITY': 'Sudan'}
# {'NAME': 'HAN YU-RO ', 'NATIONALITY': "Democratic People's Republic of Korea"}
# {'NAME': 'TSANG YUNG YUAN ', 'NATIONALITY': ''}
# {'NAME': 'HANI AL-SAYYID AL-SEBAI', 'NATIONALITY': 'Egypt'}
# {'NAME': 'SULTAN SALEH AIDA AIDA', 'NATIONALITY': 'Yemen'}
# {'NAME': 'MUHAMMAD OMAR ', 'NATIONALITY': ''}
# {'NAME': 'ABDUL RAHMAN ZAHED ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'MOHAMMAD REZA ZAHEDI ', 'NATIONALITY': ''}
# {'NAME': 'MOHAMMAD ZAHID ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'ABDUL RAUF ZAKIR ', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'IMED BEN MEKKI ZARKAOUI', 'NATIONALITY': 'Tunisia'}
# {'NAME': 'JAMAL HUSSEIN HASSAN', 'NATIONALITY': 'Syrian Arab Republic'}
# {'NAME': 'MOHAMMED SALAHALDIN ABD EL HALIM', 'NATIONALITY': 'Egypt'}
# {'NAME': 'INNOCENT ZIMURINDA ', 'NATIONALITY': 'Democratic Republic of the Congo'}
# {'NAME': 'ABDELHAFIZ ZLITNI ', 'NATIONALITY': ''}
# {'NAME': 'MERAI ABDEFATTAH KHALIL', 'NATIONALITY': 'Libya'}
# {'NAME': 'MOHAMMAD BAQER ZOLQADR ', 'NATIONALITY': ''}
# {'NAME': 'MUHAMMAD HAMZA ZUBAIDI', 'NATIONALITY': 'Iraq'}
# {'NAME': 'Ahmad Oumar Imhamad', 'NATIONALITY': 'Libya'}
# {'NAME': 'Abd Al-Rahman al-Milad', 'NATIONALITY': 'Libya'}
# {'NAME': 'Amir Muhammad Sa’id Abdal-Rahman', 'NATIONALITY': 'Iraq'}
# {'NAME': 'FAIZULLAH KHAN NOORZAI', 'NATIONALITY': 'Afghanistan'}
# {'NAME': 'SAID JAN ‘ABD AL-SALAM ', 'NATIONALITY': 'Afghanistan'}
# True

# %%
df_edges = pd.DataFrame(link_list, columns=['Source', 'Target', 'SourceName'] )
df_edges.to_csv('un_indiv_edges.csv', index=False)
graph = dict(zip(df_ind_norm.REFERENCE_NUMBER, df_ind_norm.TARGETS))
print(len(graph.keys()))  # ind, 703
# Out:
# 703

# %%
# S=pd.Series(['Finland','Colombia','Florida','Japan','Puerto Rico','Russia','france'])
# [itm[0] for itm in S.str.findall('^[Ff].*') if len(itm)>0]

# %%
import networkx as nx
dol = {0: [1]}  # single edge (0,1)
G0 = nx.from_dict_of_lists(dol)
list(G0.edges(data=True))
# Out:
# [(0, 1, {})]

# %%
# G = nx.Graph(graph)  # use Graph constructor
G = nx.from_dict_of_lists(graph)
# list(G.edges)
for n, edge in enumerate(list(G.edges(data=True))):
    if n < 10:
        print(edge)
    else:
        break
# Out:
# ('QDi.430', 'QDe.115', {})
# ('QDi.400', 'QDe.137', {})
# ('QDi.343', 'QDe.004', {})
# ('QDi.343', 'QDe.137', {})
# ('QDi.343', 'QDe.115', {})
# ('TAi.155', 'TAe.012', {})
# ('TAi.155', 'TAi.144', {})
# ('QDi.012', 'QDe.098', {})
# ('QDi.192', 'QDe.003', {})
# ('TAi.024', 'TAi.145', {})
